# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('customer.csv')

# %%
data.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
df = data.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,0:2], df.iloc[:,-1], test_size=0.2)

# %%
X_train
# Out:
#      review education
# 32  Average        UG
# 8   Average        UG
# 16     Poor        UG
# 12     Poor    School
# 25     Good    School
# 22     Poor        PG
# 26     Poor        PG
# 48     Good        UG
# 11     Good        UG
# 46     Poor        PG
# 21  Average        PG
# 28     Poor    School
# 23     Good    School
# 33     Good        PG
# 39     Poor        PG
# 0   Average    School
# 36     Good        UG
# 47     Good        PG
# 35     Poor    School
# 29  Average        UG
# 14     Poor        PG
# 13  Average    School
# 31     Poor    School
# 30  Average        UG
# 4   Average        UG
# 40     Good    School
# 15     Poor        UG
# 49     Good        UG
# 18     Good    School
# 3      Good        PG
# 24  Average        PG
# 2      Good        PG
# 42     Good        PG
# 38     Good    School
# 1      Poor        UG
# 10     Good        UG
# 45     Poor        PG
# 6      Good    School
# 20  Average    School
# 37  Average        PG

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories= [['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
X_train = X_train.fillna('missing')
X_test = X_test.fillna('missing')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 X_train = X_train.fillna('missing')
#       2 X_test = X_test.fillna('missing')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'fillna'

# %%
X_train = oe.transform(X_train)
X_test = oe.transform(X_test)
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 X_train = oe.transform(X_train)
#       2 X_test = oe.transform(X_test)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\preprocessing\_encoders.py:1578, in OrdinalEncoder.transform(self, X)
#    1564 """
#    1565 Transform X to ordinal codes.
#    1566
#    (...)
#    1575     Transformed input.
#    1576 """
#    1577 check_is_fitted(self, "categories_")
# -> 1578 X_int, X_mask = self._transform(
#    1579     X,
#    1580     handle_unknown=self.handle_unknown,
#    1581     force_all_finite="allow-nan",
#    1582     ignore_category_indices=self._missing_indices,
#    1583 )
#    1584 X_trans = X_int.astype(self.dtype, copy=False)
#    1586 for cat_idx, missing_idx in self._missing_indices.items():
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\preprocessing\_encoders.py:206, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     204 for i in range(n_features):
#     205     Xi = X_list[i]
# --> 206     diff, valid_mask = _check_unknown(Xi, self.categories_[i], return_mask=True)
#     208     if not np.all(valid_mask):
#     209         if handle_unknown == "error":
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_encode.py:304, in _check_unknown(values, known_values, return_mask)
#     301         valid_mask = np.ones(len(values), dtype=bool)
#     303 # check for nans in the known_values
# --> 304 if np.isnan(known_values).any():
#     305     diff_is_nan = np.isnan(diff)
#     306     if diff_is_nan.any():
#     307         # removes nan from valid_mask
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
