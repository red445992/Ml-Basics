# %% [markdown]
# # Feature Scaling

# %% [markdown]
# #### Lets test what will happen to the model if the scaling is not done.

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
data = load_iris()
x = data.data
y = data.target

# %%
#artifically increase the value of x
x[:,0] = x[:,0]*1000 
x[:,0]
# Out:
# array([5.1e+09, 4.9e+09, 4.7e+09, 4.6e+09, 5.0e+09, 5.4e+09, 4.6e+09,
#        5.0e+09, 4.4e+09, 4.9e+09, 5.4e+09, 4.8e+09, 4.8e+09, 4.3e+09,
#        5.8e+09, 5.7e+09, 5.4e+09, 5.1e+09, 5.7e+09, 5.1e+09, 5.4e+09,
#        5.1e+09, 4.6e+09, 5.1e+09, 4.8e+09, 5.0e+09, 5.0e+09, 5.2e+09,
#        5.2e+09, 4.7e+09, 4.8e+09, 5.4e+09, 5.2e+09, 5.5e+09, 4.9e+09,
#        5.0e+09, 5.5e+09, 4.9e+09, 4.4e+09, 5.1e+09, 5.0e+09, 4.5e+09,
#        4.4e+09, 5.0e+09, 5.1e+09, 4.8e+09, 5.1e+09, 4.6e+09, 5.3e+09,
#        5.0e+09, 7.0e+09, 6.4e+09, 6.9e+09, 5.5e+09, 6.5e+09, 5.7e+09,
#        6.3e+09, 4.9e+09, 6.6e+09, 5.2e+09, 5.0e+09, 5.9e+09, 6.0e+09,
#        6.1e+09, 5.6e+09, 6.7e+09, 5.6e+09, 5.8e+09, 6.2e+09, 5.6e+09,
#        5.9e+09, 6.1e+09, 6.3e+09, 6.1e+09, 6.4e+09, 6.6e+09, 6.8e+09,
#        6.7e+09, 6.0e+09, 5.7e+09, 5.5e+09, 5.5e+09, 5.8e+09, 6.0e+09,
#        5.4e+09, 6.0e+09, 6.7e+09, 6.3e+09, 5.6e+09, 5.5e+09, 5.5e+09,
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
model = KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy without scaling:", model.score(X_test, y_test))
# Out:
# Accuracy without scaling: 0.23333333333333334

# %% [markdown]
# # Now lets see how scaling will improve the model accuracy

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
min_max_scaler = MinMaxScaler()
X_train_minmax = min_max_scaler.fit_transform(X_train)
X_test_minmax = min_max_scaler.transform(X_test)

# %%
x_min = min_max_scaler.fit_transform(x)
x_min
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
model_minmax = KNeighborsClassifier()

# %%
model_minmax.fit(X_train_minmax, y_train)
print("Accuracy with MinMaxScaler:", model_minmax.score(X_test_minmax, y_test))
# Out:
# Accuracy with MinMaxScaler: 0.9333333333333333

# %%
standard_scaler = StandardScaler()
X_train_std = standard_scaler.fit_transform(X_train)
X_test_std = standard_scaler.transform(X_test)

# %%
model_std = KNeighborsClassifier()

# %%
model_std.fit(X_train_std,y_train)
model_std.score(X_test_std,y_test)
# Out:
# 0.9333333333333333
