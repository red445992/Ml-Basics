# %% [markdown]
# # chart Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(1000)
np.random.randn(1000)
# Out:
# array([-8.04458304e-01,  3.20931547e-01, -2.54828805e-02,  6.44323828e-01,
#        -3.00796673e-01,  3.89474554e-01, -1.07437302e-01, -4.79983075e-01,
#         5.95035502e-01, -4.64667526e-01,  6.67281307e-01, -8.06115610e-01,
#        -1.19606983e+00, -4.05960161e-01, -1.82377340e-01,  1.03192894e-01,
#        -1.38421989e-01,  7.05692375e-01,  1.27179528e+00, -9.86747329e-01,
#        -3.34835453e-01, -9.94816980e-02,  4.07192100e-01,  9.19387539e-01,
#         3.12118010e-01,  1.53316107e+00, -5.50173865e-01, -3.83147411e-01,
#        -8.22940963e-01,  1.60008337e+00, -6.92812989e-02,  8.32094921e-02,
#        -3.26924675e-01, -4.57971880e-02, -3.04460062e-01,  1.92301013e+00,
#        -7.86590035e-02, -5.82065723e-01, -1.61798224e+00,  8.67260817e-01,
#        -1.04043709e+00,  6.50421425e-01,  2.69964586e+00,  8.02024514e-01,
#        -1.09692126e+00, -1.78054446e-01, -4.22870478e-01, -3.30400548e-01,
#        -1.11116278e+00, -7.42005751e-01,  2.57475919e+00,  1.07321332e+00,
#        -1.86613451e+00, -6.47176927e-01,  1.08224081e+00,  1.76670316e-01,
#        -8.35328233e-01, -1.69499832e+00,  1.13341723e+00,  1.04853072e+00,
#        -2.12832537e+00, -1.43713939e+00,  1.77937106e-01,  1.39442275e+00,
#         2.91320186e-01, -8.20061940e-02,  6.44242612e-01,  3.28079948e-01,
#         8.57432749e-01, -9.36969281e-01,  1.80074956e-01, -1.42337059e+00,
#        -3.67755778e-01, -1.52328799e+00, -6.34771699e-01,  9.87403842e-01,
#        -1.01601962e+00,  2.04572375e+00,  2.49998519e-01,  6.51162530e-01,
#        -1.26602354e+00,  1.37415560e+00, -6.09905129e-01,  3.07579452e-02,
#         8.19656677e-01,  1.45431373e+00, -5.83676446e-01,  4.15347452e-01,
#         6.67025778e-01,  8.69495302e-01, -1.20270333e+00,  2.86176918e+00,
#        -2.68159245e+00, -1.16881176e+00, -5.84164223e-01,  8.18249697e-01,
#         1.59043723e+00, -2.58288232e-01,  4.47029039e-01,  1.93841974e+00,
#        -3.90319350e-01, -5.80696338e-01,  1.94898697e+00, -1.86255134e+00,
#        -5.68356576e-01,  9.79224025e-01,  8.95363889e-01, -2.36262449e-01,
#         4.41097932e-01, -9.92413992e-01,  2.95504986e-01,  4.21596938e-02,
#         7.62139021e-01,  6.27956474e-01,  1.07123244e-01, -1.55526284e+00,
#        -2.90585418e+00,  7.55762834e-01, -1.29956225e+00, -8.65022488e-01,
#        -1.18799428e+00, -9.78814508e-01, -1.96300125e+00, -4.78531195e-01,
#         1.08223608e+00,  1.10308709e+00,  6.89981455e-01,  3.21378761e-01,
#        -6.00465224e-01, -1.69709446e-01, -1.39456835e+00, -2.13248289e-01,
#         1.28449338e+00,  5.85636339e-01, -5.68272147e-01, -4.38311999e-02,
#         9.52586745e-01, -3.27375428e-01, -4.57698253e-01,  3.51326018e-01,
#        -3.59439233e-01, -5.14498233e-01, -9.91114667e-01, -1.23731715e+00,
#        -6.62489529e-01,  7.57102583e-01, -1.25981812e+00, -6.65985942e-01,
#         3.87700915e-01,  1.14829037e+00,  9.10485829e-01, -1.86280869e-01,
#        -9.99876173e-01, -1.13493354e+00,  6.37671916e-01, -2.44278612e-01,
#         2.35716709e-01, -9.47522805e-01,  6.97369165e-01,  8.83317001e-01,
#         4.22883213e-01, -3.98451727e-01,  1.99243064e-01, -6.22635063e-01,
#        -4.45053623e-01, -1.53138209e+00, -7.97441233e-02, -1.59213106e+00,
#         1.75151805e-01, -1.79209305e+00, -1.98285664e+00, -5.90410926e-01,
#        -2.90518149e-01,  8.21016376e-01, -7.09275019e-01, -5.35681392e-02,
#        -8.62036675e-01,  7.74018183e-01,  6.45667615e-01, -8.41205973e-01,
#         1.76281060e+00, -6.04148006e-01, -3.85857609e-01, -5.01005673e-01,
#         5.82234854e-01, -4.71867669e-01, -1.15990877e+00,  9.22108223e-01,
#        -4.11882839e-01,  4.01821902e-01,  2.27904002e+00,  9.72151068e-01,
#         1.19971955e-01, -2.16209451e+00, -7.94352403e-01, -1.74778079e-01,
#        -5.29062727e-01,  3.77807580e-02, -1.41088367e+00,  8.39709712e-01,
#        -1.11573322e+00, -1.34477121e+00,  7.53343740e-01,  2.00927039e+00,
#        -6.32569224e-01, -2.47982948e-01,  4.12862339e-01, -9.24232528e-01,
#         1.37342792e+00, -2.74967767e+00,  2.31285488e-02, -3.41669172e-01,
#        -1.13725533e+00,  1.13437686e+00, -1.25803771e+00, -1.76426234e+00,
#         1.95315661e-01, -2.82273671e+00, -8.30051447e-01,  8.73942870e-01,
#         1.42747902e+00, -6.80861947e-01,  1.96589679e+00,  6.57740424e-01,
#         1.63460334e+00, -3.61164656e-01, -2.31986154e-01,  1.48934662e+00,
#        -3.25314145e-01, -1.03511138e+00, -1.10553546e+00,  6.61163917e-01,
#        -5.40413934e-01, -1.71806693e+00, -3.36429740e-01,  7.44706574e-01,
#        -4.21440757e-01,  5.31604304e-01,  7.36768174e-01,  3.49369666e-01,
#         2.79165467e-01, -5.44525657e-01,  1.04664684e+00, -1.93760051e+00,
#        -9.05878830e-01,  1.51050951e+00, -1.34731603e+00, -3.04137957e-01,
#        -4.96696009e-03, -7.54207488e-01, -7.78034424e-01,  1.43843445e-02,
#        -1.31765744e+00,  6.75736069e-01, -3.95203065e-01, -5.51232398e-01,
#         1.25463321e+00, -5.81261949e-01,  2.37118611e-01,  1.67133345e+00,
#         2.05563111e-01, -6.65862186e-02, -2.15119837e+00, -7.93210178e-01,
#         6.20613084e-01, -2.79962844e-01,  4.66928935e-01,  4.24802943e-01,
#        -1.24297409e+00,  7.05147910e-01, -1.30994991e-01, -1.54240326e+00,
#        -1.17437258e+00, -2.42441508e-01, -1.49756081e+00,  1.75689288e+00,
#        -1.10157899e+00, -2.29938374e+00,  1.00578114e+00, -2.10550419e+00,
#         1.34260269e+00,  5.24464269e-01, -1.18058704e-01, -5.94405326e-01,
#         3.65818706e-02,  9.08063048e-01,  9.96708648e-01,  1.88265059e-01,
#        -4.13103517e-01, -9.36358706e-01, -2.71810747e-01, -1.09820752e+00,
#        -1.20937305e+00,  2.38406460e-01, -1.09620324e+00,  6.04722022e-02,
#         4.86553502e-01,  9.89401727e-01,  1.90939628e+00, -8.29618512e-01,
#         4.24006990e-01, -1.56680276e+00,  7.64998946e-01,  3.87625480e-01,
#         1.13787252e+00, -3.09108955e-01,  5.79357212e-01, -1.03126262e+00,
#         2.79851190e-02,  1.27980024e+00,  4.62605724e-01,  2.35474332e-01,
#        -6.56010136e-01, -2.18416362e+00, -4.94507387e-04, -5.26103048e-01,
#         8.88520272e-01, -9.87727438e-01,  2.19147368e-01, -4.30307070e-01,
#        -2.16798779e-01,  4.48390052e-01,  6.61749858e-01,  5.03481664e-01,
#        -3.65872593e-01,  7.36742879e-01, -6.48545137e-01,  3.76234901e-01,
#         1.31414105e-02, -1.51498349e+00,  1.96025814e+00,  1.37190845e+00,
#        -1.57418016e+00, -1.45575845e+00,  9.83264976e-02, -2.32605118e+00,
#         1.32471268e+00,  4.11873705e-01,  5.91773578e-01, -2.88772603e-01,
#         3.60538058e-01,  6.28807277e-01, -7.28919609e-01, -6.92993306e-01,
#        -6.77031480e-01,  3.29414794e-03,  1.32901669e-01,  9.63391600e-01,
#         3.84443730e-01,  1.33039967e+00, -9.23129417e-01, -1.13075580e+00,
#        -1.46722519e+00,  2.25679193e-01,  1.64168434e-01, -6.57986368e-01,
#        -1.26360218e+00,  8.14755640e-01, -6.57207002e-01,  1.25656900e+00,
#        -9.36221444e-02, -1.18178204e+00,  3.94044283e-01,  9.62953792e-01,
#        -5.76479393e-01, -8.49873587e-01,  2.22821189e-01,  4.07704478e-01,
#         7.77419356e-01,  5.67180407e-02,  1.26109325e-02,  8.65131266e-01,
#        -6.36111674e-01,  2.06085954e+00,  1.98173786e+00,  6.36507488e-01,
#         1.16115169e+00, -6.13947033e-01, -1.33205700e-02, -2.92551675e-01,
#        -1.02504866e+00,  1.61511441e+00,  6.71912879e-01, -1.17264155e+00,
#        -2.40556417e-01, -1.23833775e+00,  2.49995679e-01,  2.79425803e-01,
#         1.03009493e+00,  8.35574053e-01, -3.45366636e-02, -3.22656735e-01,
#        -1.26897112e-02,  1.96226489e+00,  9.13136029e-01, -8.84592614e-02,
#        -1.57847578e-01, -3.37319741e-01, -3.19582518e-01,  1.26889969e+00,
#        -1.74866738e+00, -6.91302064e-02,  1.52621653e+00,  5.31191345e-01,
#        -5.72944034e-01, -3.07910626e-01,  5.24594968e-02,  1.71734847e+00,
#         1.66936691e+00,  3.10709757e-01,  2.26606158e-01, -1.12794797e+00,
#         1.35012105e+00, -1.33832962e+00,  1.73037400e+00,  1.94772513e+00,
#         3.37391346e-01,  1.65165286e+00,  3.02351049e-01, -8.88027604e-01,
#         5.21866004e-01,  2.73004576e-03,  9.99476324e-01,  6.59870768e-01,
#         4.42304366e-01, -9.92245623e-01,  2.15511958e-01,  9.03906982e-01,
#         1.93197483e+00,  5.54627694e-01, -8.75528515e-01, -8.75055894e-01,
#        -1.27856414e+00,  7.65764161e-01,  4.40074983e-01, -5.62264762e-01,
#         1.56666296e+00, -5.15481602e-01,  1.96678062e+00,  1.14343653e+00,
#         7.13909448e-01, -2.16498179e-01, -1.04684494e+00,  8.74476363e-01,
#        -2.26973042e-01, -5.82369613e-01, -8.25365226e-01, -1.09088812e-01,
#        -2.63101136e-01,  1.34243687e+00,  3.40365755e-02,  8.40808704e-01,
#         2.22255712e-01,  1.18509524e+00, -1.28085343e+00,  1.07492098e-01,
#        -4.21289608e-01, -1.09257966e+00,  9.85433594e-01, -2.82502601e-01,
#        -4.83004496e-01,  7.93019513e-01, -1.56667058e+00,  6.93590096e-01,
#         1.06263059e+00, -2.51538820e-01,  1.07417503e+00,  1.48756148e+00,
#        -4.67942376e-01, -1.74679093e+00, -2.70578348e-01, -7.48915345e-01,
#        -7.82634219e-01, -2.26680900e-01, -2.39659426e+00, -3.86691803e-01,
#        -4.50431174e-01, -8.53417003e-01,  8.10875478e-01,  1.04171963e+00,
#        -8.29122511e-01,  2.84497618e-01, -2.93439282e-01,  1.24198214e+00,
#         3.43465567e-01,  1.00092080e+00, -4.54904861e-01, -1.25815759e+00,
#        -6.67502530e-01, -3.85379939e-01, -2.48259559e+00,  2.88283280e-01,
#        -1.15637392e-01,  6.88298455e-01, -1.47301872e-01,  1.19929214e+00,
#         1.04734756e+00,  3.95852263e-01, -3.61657325e-01, -4.14924743e-03,
#        -1.47413489e-01,  1.39598928e+00,  4.37599580e-01, -1.87573519e+00,
#         1.75681417e+00,  6.51082364e-01,  2.10463728e+00,  9.88566466e-01,
#         1.59773048e+00, -4.60888282e-01, -4.14788708e-01,  1.29600516e+00,
#        -4.33190603e-01,  4.44761922e-01,  1.43830820e+00, -1.12357669e+00,
#        -9.39702142e-01, -1.55244219e+00,  4.21328887e-01, -1.51784634e+00,
#         1.67585386e+00, -9.07623801e-01, -7.86423488e-01, -1.35781888e+00,
#        -8.39023490e-01, -1.21719112e+00, -1.77681693e-01,  6.87298780e-01,
#         1.09394863e+00,  1.38770303e+00,  1.27270049e+00,  3.41376796e-01,
#         1.69511146e+00, -9.97416138e-03,  5.22955898e-01, -1.41596396e+00,
#         5.08118430e-01,  3.41447069e-01,  5.36933965e-01,  1.95453734e-01,
#         1.25469858e+00,  2.38139807e+00,  1.00431052e+00, -2.80664092e-01,
#        -1.31390695e+00, -3.35108842e-01, -2.53175235e+00, -1.93567176e-01,
#         1.01461890e+00,  1.20948775e+00,  2.57702967e+00, -1.81978716e-01,
#         1.91027283e-01, -3.19969067e-01, -1.00047459e+00,  7.45864823e-01,
#        -2.44485098e+00, -3.55577289e-01, -4.33167837e-01,  1.55527547e+00,
#        -2.89493706e-01, -1.18003438e+00,  8.05688160e-01, -6.67868993e-01,
#        -2.93514548e-01, -2.84393785e-01,  4.11236113e-01, -1.36042570e-01,
#        -5.30374894e-01,  4.48355020e-01,  1.01237180e+00, -1.82168956e-01,
#        -1.53436633e+00,  5.79458104e-01, -1.10543602e-01, -3.32141894e-01,
#        -1.35556110e+00, -8.03579633e-01, -5.27400797e-01, -3.50367313e-02,
#         9.56927330e-01,  1.51299928e+00, -4.12497852e-01,  9.77005142e-02,
#         4.53603869e-01,  9.06519108e-02, -5.32881587e-01,  5.64431764e-02,
#         4.10314502e-01,  2.76316996e-01,  1.05694905e+00,  1.67425069e+00,
#        -5.21044922e-01, -4.64624166e-01,  2.07206509e-01,  6.77547443e-01,
#         6.89168856e-01,  3.57066020e-01,  6.09956630e-01, -1.53224531e-01,
#         1.17955921e+00, -3.05213151e-01, -9.75532907e-01, -4.52449410e-01,
#         1.07557345e+00,  2.86160899e-01,  3.36519192e-01,  1.82842965e-01,
#         1.19196006e+00, -1.60222162e-01, -4.06210891e-01,  2.20130126e+00,
#        -1.13569126e+00,  8.25330829e-01,  5.13131883e-01, -1.99205939e-01,
#        -2.25020241e+00,  1.11592565e+00, -1.77927724e-01,  6.91876359e-01,
#         6.80614541e-01, -2.68634371e-01, -9.74208196e-01,  4.42534701e-01,
#         6.62598684e-01,  6.43930472e-01,  1.64539560e-01, -1.20778750e+00,
#         2.17370711e+00, -2.69824512e+00,  1.51150036e+00,  1.77143886e-01,
#         1.89682554e+00, -1.31253057e+00, -3.11440339e-01,  7.61650340e-01,
#        -1.99164699e+00, -8.58907169e-01,  1.16906335e+00,  5.28322350e-01,
#         6.21782038e-01,  7.07592239e-02,  3.52489550e-01,  1.03457634e+00,
#        -5.72318324e-01, -1.38282005e+00,  3.86656707e-01,  1.97518181e+00,
#        -2.16566804e-01, -9.33113882e-01, -2.62695446e-01,  1.01005937e+00,
#        -1.26115541e+00,  2.17948870e+00, -2.73516516e+00, -7.27196278e-01,
#         1.48653593e-01,  7.73142361e-01, -2.18269784e-01, -1.71779962e-01,
#         1.13161831e+00,  2.15331721e-01, -1.94027205e+00,  6.62762594e-02,
#        -8.03220394e-02, -1.25121348e+00, -6.42818584e-01, -1.42596575e+00,
#         3.36910340e-01, -5.70649473e-01, -8.03005005e-01, -3.78649502e-01,
#        -8.60069960e-02,  3.56115576e-01, -1.16606243e+00, -3.04834428e-01,
#         2.90400078e-01,  3.38807578e-01, -8.41356589e-01, -1.18310852e+00,
#        -5.24824336e-01,  2.53094166e-01,  1.73588242e+00,  1.89487009e+00,
#         7.31117836e-01, -2.12311724e-01,  1.97109549e+00,  4.04236419e-01,
#        -1.53088149e-01, -7.98957773e-01, -2.48085988e-02,  1.90464632e-01,
#        -1.68858606e+00,  2.37578285e-02,  8.11253422e-02,  5.98498798e-01,
#        -1.94997739e-01,  1.64555414e-01, -8.40241967e-01, -8.94195394e-01,
#        -1.41095341e+00,  4.87011543e-01,  1.02199628e-01,  1.39443328e+00,
#        -3.47692223e-01, -1.78709692e+00, -7.50668152e-01, -7.85986135e-01,
#        -2.32535362e+00,  1.30966484e+00, -5.29360488e-01,  2.53004396e-01,
#         2.87120667e+00, -1.04134915e+00, -1.63231974e-01, -5.31200385e-02,
#        -6.28627633e-01, -4.44315277e-01,  1.06289000e+00, -1.76124362e+00,
#         1.69057757e-01, -5.82261703e-01,  1.62488468e+00, -6.52427251e-01,
#        -7.33812322e-01, -9.28879989e-01,  1.65776647e-01,  8.25808271e-01,
#         6.72441262e-02,  1.10432848e+00,  1.67474229e-02, -1.07285767e+00,
#         2.43952498e-01, -1.16475130e+00, -1.27270691e+00,  6.21331427e-01,
#        -8.55944369e-02, -1.14501333e+00, -3.39973111e-01, -1.74060021e-01,
#        -5.34203614e-01, -5.16854776e-01,  1.09103932e+00, -5.08319329e-01,
#        -1.87511164e+00, -1.72001606e+00, -1.82928207e+00, -5.65477433e-01,
#         1.60370156e+00, -1.52202122e+00, -1.40319794e+00,  4.92905715e-01,
#         3.61162593e-02, -2.54045463e-01, -6.27820612e-02,  3.67126021e-02,
#         1.23607352e+00, -3.82207897e-01, -1.06097735e+00, -1.25757736e+00,
#        -1.31291602e-01, -5.38155688e-01,  8.57022741e-01,  1.16047444e+00,
#         3.30902954e-02, -2.81140820e-01, -1.55676806e+00, -1.18472408e+00,
#        -5.38984808e-01,  8.31221887e-01,  1.48175545e+00,  6.77609398e-01,
#        -3.16563399e-01, -1.12803847e+00, -8.55027193e-01, -1.83210642e-01,
#         8.80629935e-01,  3.08010598e-01, -2.21038433e+00,  1.40405284e+00,
#         6.77990418e-01, -9.64881488e-01, -2.34474380e+00, -4.11487627e-01,
#        -5.21910113e-01,  7.54302699e-01,  5.63192544e-01,  1.45087253e+00,
#        -6.31618970e-01,  1.98357343e+00, -1.28278457e+00,  6.26266676e-01,
#        -1.58245129e-01,  1.23945172e+00,  2.92237924e-01, -4.36001155e-01,
#         9.82139907e-01,  8.13988835e-01, -1.54917755e+00,  9.03550510e-01,
#         1.28930404e-01, -1.49614180e-02, -6.75070687e-01, -1.20698375e+00,
#         4.38433768e-01,  7.57043785e-02,  5.43410645e-01,  9.93143839e-01,
#         2.58196279e-02,  1.51638881e+00, -1.90114976e-01,  3.21435328e-02,
#        -1.74131621e+00,  7.22777793e-01, -1.57108201e+00,  4.95449114e-01,
#        -7.85034511e-01,  7.12031894e-01,  1.19657883e+00, -3.70277945e-01,
#         1.05397309e-02,  1.25107883e+00,  6.81405865e-02, -7.12087391e-01,
#         7.37870399e-01, -3.49787207e-01,  3.39881821e-01,  1.19717246e+00,
#         1.53855819e-01,  2.39547604e-02, -1.46516312e+00,  9.62766450e-01,
#         3.33712172e-01, -1.31301227e+00, -5.70907590e-01,  3.71055081e-01,
#        -3.44576104e-01, -1.95497783e-01,  1.46674272e+00, -3.17455165e-02,
#        -1.28909837e-01,  2.27518702e-01,  5.56558023e-01,  1.96017357e-01,
#         3.61014730e-03, -1.05497748e+00,  7.67357449e-01, -4.04454271e-01,
#        -3.61231082e-01, -9.55611454e-02, -9.86273167e-01, -3.17378003e+00,
#         1.75583254e+00, -1.34054801e+00, -2.23163536e-01,  1.21999821e+00,
#        -9.18808369e-01,  1.19557969e+00,  8.80263327e-01, -1.80968732e+00,
#        -1.58150852e-01, -2.06277293e-01,  9.11705976e-01, -1.48016464e+00,
#        -8.29926153e-01,  3.35369352e-01,  3.51795869e-01,  2.48200438e-01,
#         8.22361248e-01, -5.53468538e-01,  4.19845882e-01,  3.73761848e-01,
#         5.55882340e-01,  6.22271550e-01, -8.57234903e-01, -3.46371416e-01,
#         8.96667065e-01, -6.21450539e-01, -3.84818156e-02, -1.75290233e+00,
#         1.14174777e-01, -3.16064567e+00,  1.39715929e+00, -1.07223783e+00,
#         2.97465546e-01,  6.50956611e-01,  5.05142150e-01,  1.88721922e+00,
#        -1.55840296e-01,  1.87455597e-01, -1.05682306e+00, -4.57412102e-01,
#         1.36894737e+00,  2.48739919e+00, -1.99312831e+00, -6.75411922e-01,
#        -1.18766493e+00, -3.98054502e-01,  2.07373177e-01, -8.30802321e-01,
#        -9.43086023e-01, -6.00078060e-01,  8.19485766e-01,  5.00987275e-01,
#        -6.27955932e-01,  5.68857909e-01,  7.82429642e-01,  4.26916788e-01,
#         8.13688259e-01,  2.96604243e-01,  6.22157865e-01,  1.44526924e-01,
#        -1.62478794e-01,  1.64839425e+00,  1.15886030e+00,  5.62994911e-01,
#         8.33979080e-01, -1.28153957e-01,  1.72031469e+00, -1.24667557e+00,
#        -1.34275895e+00,  9.78818649e-01, -1.17323250e+00,  1.66016393e-01,
#         5.84996250e-01,  4.59697425e-02, -8.47536166e-01, -1.47774179e+00,
#        -1.86903748e+00, -2.54437681e-01, -1.64266573e+00, -5.00439983e-01,
#         5.29266887e-01,  2.01816551e+00,  9.69496609e-01,  2.31472044e+00,
#        -4.18512952e-01,  1.06472256e+00,  1.28980431e-01, -1.03624803e-01,
#         4.47291107e-02,  8.28717233e-01,  8.93139159e-01,  6.86522491e-01,
#        -2.74558972e-01,  3.41998900e-01,  1.92283574e+00, -4.36414470e-01,
#         5.85864500e-01, -7.65193933e-02,  1.37437407e-02, -1.03215427e+00,
#         3.41208007e-01, -1.69533022e+00, -2.89167293e-01, -1.12011402e-01,
#        -3.37572071e-01, -1.09513321e+00,  6.34935066e-01,  1.68873165e-01,
#        -1.79439950e-01, -1.18589419e+00, -2.97628637e-02, -7.47062912e-02,
#         1.01710432e+00, -1.73040247e-01,  1.75083784e-01,  4.68890608e-01,
#        -3.91249199e-01,  1.75405314e+00, -8.73536914e-01, -2.94530510e-01,
#        -1.23517019e+00,  1.38271607e-01, -4.24943443e-02,  1.29578739e+00,
#         4.75768519e-01, -6.41223446e-02, -1.02178225e+00,  7.63332141e-01,
#         2.27228990e-01, -6.55245939e-01,  5.98547344e-01,  1.24800479e+00,
#         3.68625481e-01,  1.02653118e+00, -1.04875552e-01, -7.47918180e-01,
#         1.32013318e+00,  7.81987240e-01, -4.64159729e-01, -7.70848379e-01,
#        -9.08484915e-01, -5.86311348e-01,  2.28118251e+00,  5.87763564e-02,
#        -2.16289962e-02,  1.88094041e-01,  3.33698831e-01, -3.47050885e-02])

# %%
ts = pd.DataFrame(np.random.randn(1000),index=pd.date_range('1/1/2020',periods=1000))
ts = ts.cumsum()
ts
# Out:
#                    0
# 2020-01-01  0.607963
# 2020-01-02  1.546426
# 2020-01-03  0.698148
# 2020-01-04  1.577484
# 2020-01-05  1.417960
# ...              ...
# 2022-09-22  6.168009
# 2022-09-23  5.109049
# 2022-09-24  5.852879
# 2022-09-25  5.097318
# 2022-09-26  4.989896
#
# [1000 rows x 1 columns]

# %%
ts.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,4),index=ts.index,columns=list("ABCD"))
df = df.cumsum()
plt.figure()
df.plot()
# Out:
# <Axes: >

# %%
df
# Out:
#                    A          B          C         D
# 2020-01-01 -1.211588  -0.726774   0.469858  0.696137
# 2020-01-02 -1.813344  -3.178590   0.274515  0.737371
# 2020-01-03 -1.633053  -4.130305   0.190359  0.039671
# 2020-01-04 -2.235422  -6.387896  -0.347435  1.502805
# 2020-01-05 -1.135573  -8.573713  -2.890569  1.001054
# ...              ...        ...        ...       ...
# 2022-09-22 -3.310605 -45.377673 -10.237966  8.761274
# 2022-09-23 -4.477331 -44.772961  -9.477699  8.099200
# 2022-09-24 -4.667253 -44.643498  -8.266586  9.465770
# 2022-09-25 -6.182823 -45.095674  -8.645831  7.505977
# 2022-09-26 -5.669580 -42.619984  -8.850673  7.821221
#
# [1000 rows x 4 columns]

# %%
np.random.randn(1000,2)
# Out:
# array([[-0.97478124,  1.8821924 ],
#        [ 0.76747198,  0.93841374],
#        [-0.5456748 , -1.98504265],
#        ...,
#        [-1.10356958, -1.05883661],
#        [-1.71196947,  0.3557458 ],
#        [ 0.13904374, -0.25549604]])

# %%
df2 = pd.DataFrame(np.random.randn(1000,2),columns=['B','C']).cumsum()
df2['A']=pd.Series(list(range(len(df)))).cumsum()
df2.plot(x="A",y="B")
# Out:
# <Axes: xlabel='A'>

# %%
df
plt.figure()
df.iloc[5].plot(kind="bar")
# Out:
# <Axes: >

# %%
np.random.randn(10,4)
# Out:
# array([[ 0.61020084,  0.6217954 ,  0.49569386, -0.4506104 ],
#        [ 1.3263323 , -0.007964  , -1.82733717,  0.49884349],
#        [ 0.13880724, -0.63899806, -0.0522313 ,  0.60496575],
#        [-0.44294504, -1.41049049,  0.90646817, -0.69128482],
#        [-0.08718749, -0.46597495,  0.94322613,  1.03052287],
#        [-1.29432069,  0.04124939,  2.04017527, -0.76075969],
#        [ 1.02292051,  1.5985528 , -0.19563205, -0.70479068],
#        [ 0.45922681,  0.72882876,  0.27405927,  2.79821262],
#        [ 0.80052556, -1.4739447 ,  1.43877253,  1.22533586],
#        [-0.05872412, -2.06825226, -0.87371458,  1.34522383]])

# %%
df2 = pd.DataFrame(np.random.randn(10,4),columns=["A","B","C","D"])
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.hist(alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.diff().hist(color='k',alpha=0.5,bins=50)
# Out:
# array([[<Axes: title={'center': 'A'}>, <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'C'}>, <Axes: title={'center': 'D'}>]],
#       dtype=object)

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])
df.plot.area(stacked=False)
# Out:
# <Axes: >

# %%
df.plot.scatter(x="a",y='b',s=50)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x="a", y="b", reduce_C_function=np.max, gridsize=25);

# %% [markdown]
# series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")
#
# series.plot.pie(figsize=(6, 6));

# %%
series.plot.pie(
    labels=["AA", "BB", "CC", "DD"],
    colors=["r", "g", "b", "c"],
    autopct="%.2f",
    fontsize=20,
    figsize=(6, 6),
);

# %% [markdown]
# # plotting tools

# %%
from pandas.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=["a", "b", "c", "d"])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal="kde");

# %%
# density plotser = pd.Series(np.random.randn(1000))
ser = pd.Series(np.random.randn(1000))
ser.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Andrew Curves

# %%
from pandas.plotting import andrews_curves

df = pd.read_csv("../../data/Housing.csv")

plt.figure();

andrews_curves(data, "area")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 7
#       3 df = pd.read_csv("../../data/Housing.csv")
#       5 plt.figure();
# ----> 7 andrews_curves(data, "area")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_misc.py:380, in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwargs)
#     331 """
#     332 Generate a matplotlib plot for visualizing clusters of multivariate data.
#     333
#    (...)
#     377     >>> pd.plotting.andrews_curves(df, 'Name')  # doctest: +SKIP
#     378 """
#     379 plot_backend = _get_plot_backend("matplotlib")
# --> 380 return plot_backend.andrews_curves(
#     381     frame=frame,
#     382     class_column=class_column,
#     383     ax=ax,
#     384     samples=samples,
#     385     color=color,
#     386     colormap=colormap,
#     387     **kwargs,
#     388 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_matplotlib\misc.py:260, in andrews_curves(frame, class_column, ax, samples, color, colormap, **kwds)
#     256         return result
#     258     return f
# --> 260 n = len(frame)
#     261 class_col = frame[class_column]
#     262 classes = frame[class_column].drop_duplicates()
#
# TypeError: object of type 'NoneType' has no len()

# %%
## lag plot
from pandas.plotting import lag_plot

plt.figure();

spacing = np.linspace(-99 * np.pi, 99 * np.pi, num=1000)

data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(spacing))

lag_plot(data);

# %% [markdown]
# # Auto correlation plot

# %%
from pandas.plotting import autocorrelation_plot

plt.figure();

spacing = np.linspace(-9 * np.pi, 9 * np.pi, num=1000)

data = pd.Series(0.7 * np.random.rand(1000) + 0.3 * np.sin(spacing))

autocorrelation_plot(data);

# %% [markdown]
# # plotting directly with matplotlib

# %%
np.random.seed(123456)

price = pd.Series(
    np.random.randn(150).cumsum(),
    index=pd.date_range("2000-1-1", periods=150, freq="B"),
)


ma = price.rolling(20).mean()

mstd = price.rolling(20).std()

plt.figure();

plt.plot(price.index, price, "k");

plt.plot(ma.index, ma, "b");

plt.fill_between(mstd.index, ma - 2 * mstd, ma + 2 * mstd, color="b", alpha=0.2);
