# %% [markdown]
# # K Means Clustering

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [4,5,10,4,3,11,14,6,10]
y = [21,19,24,17,16,25,22,21,21]

# %%
plt.scatter(x,y)
plt.show()

# %%
data = list(zip(x,y))
data
# Out:
# [(4, 21),
#  (5, 19),
#  (10, 24),
#  (4, 17),
#  (3, 16),
#  (11, 25),
#  (14, 22),
#  (6, 21),
#  (10, 21)]

# %%
from sklearn.cluster import KMeans

inertias = []
for i in range(1,10):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)

# %%
kmeans.inertia_
# Out:
# 46.75

# %%
plt.plot(range(1,10),inertias,marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('inertia')
plt.show()

# %%
kmeans.labels_
# Out:
# array([7, 6, 5, 8, 0, 1, 3, 2, 4])

# %%
kmeans = KMeans(n_clusters =2)
kmeans.fit(data)

plt.scatter(x,y,c=kmeans.labels_)
plt.show()

# %%
centriod_x = sum(x)/len(x)
centriod_y = sum(y)/len(y)

plt.scatter(x,y,color='blue',label='Points')

plt.scatter(centriod_x,centriod_y,color="red",marker='X',s=200,label="centriod")
plt.text(centriod_x+0.2,centriod_y,f'({centriod_x:.2f}, {centriod_y:.2f})', color='red')
plt.grid(True)
plt.legend()
plt.axis('equal')
# Out:
# (2.45, 14.55, 15.55, 25.45)

# %%
center = kmeans.cluster_centers_
plt.scatter(x,y,cmap="viridis",c=kmeans.labels_,label='Data points')
plt.scatter(center[:, 0], center[:, 1], c='red', marker='X', s=200, label='KMeans Centers')

for idx,(cx,cy) in enumerate(centers):
    plt.text(c0.3,)
