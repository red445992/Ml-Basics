# %% [markdown]
# # Univariate Analysis

# %% [raw]
# Data are of two types: categorical and numerical. So Analysis these data one by one or whole at a time is know as EDA

# %% [raw]
# Univariate analysis means analyzing data one column at a time

# %% [raw]
# # first lets do Univariate Analysis on categorical Data

# %%
# 1. categorical Data
import pandas as pd

data = pd.read_csv("../data/compas-scores-two-years.csv")

# %%
data.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race  ...  v_decile_score  \
# 0  1947-04-18   69  Greater than 45             Other  ...               1
# 1  1982-01-22   34          25 - 45  African-American  ...               1
# 2  1991-05-14   24     Less than 25  African-American  ...               3
# 3  1993-01-21   23     Less than 25  African-American  ...               6
# 4  1973-01-22   43          25 - 45             Other  ...               1
#
# ...

# %% [markdown]
# # count plot

# %%
import seaborn as sns
sns.countplot(data["sex"])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
data['sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
data['sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical data

# %%
# i. Histogram
import matplotlib.pyplot as plt

plt.hist(data['age'],bins=50)
# Out:
# (array([ 37., 501., 305., 686., 332., 653., 279., 580., 476., 215., 378.,
#         171., 329., 147., 220., 104., 225., 221.,  99., 182.,  96., 208.,
#          87., 154.,  93., 121.,  85.,  43.,  49.,  19.,  37.,  21.,  26.,
#          11.,   3.,   6.,   4.,   5.,   1.,   2.,   0.,   2.,   0.,   0.,
#           0.,   0.,   0.,   0.,   0.,   1.]),
#  array([18.  , 19.56, 21.12, 22.68, 24.24, 25.8 , 27.36, 28.92, 30.48,
#         32.04, 33.6 , 35.16, 36.72, 38.28, 39.84, 41.4 , 42.96, 44.52,
#         46.08, 47.64, 49.2 , 50.76, 52.32, 53.88, 55.44, 57.  , 58.56,
#         60.12, 61.68, 63.24, 64.8 , 66.36, 67.92, 69.48, 71.04, 72.6 ,
#         74.16, 75.72, 77.28, 78.84, 80.4 , 81.96, 83.52, 85.08, 86.64,
#         88.2 , 89.76, 91.32, 92.88, 94.44, 96.  ]),
#  <BarContainer object of 50 artists>)

# %%
# Distplot (pdf)
sns.distplot(data['age'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11052\1854398886.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
# box plot
sns.boxplot(data['age'])
# Out:
# <Axes: ylabel='age'>
